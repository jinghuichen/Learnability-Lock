# %%
from utils import *
from LearnabilityLock import *
from model import ResNet, DenseNet
import dataset
import matplotlib.pyplot as plt
# from IPython.core.interactiveshell import InteractiveShell
# InteractiveShell.ast_node_interactivity = "all"

# %%
train_loader,test_loader = dataset.load_cifar10(256)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
base_model = ResNet.ResNet18(10)
base_model = base_model.cuda()

# %%
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(params=base_model.parameters(), lr=0.1, weight_decay=0.001, momentum=0.9)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=20, eta_min=0.001)

# %%
params = {'in_shape':32, 
               'n_channel':3, 
               'n_class':10,
               'mid_planes':32 }
lock = iResLock(lock_params = params, epsilon=8/255)

# %%
def weights_init(m):
    if isinstance(m, nn.Conv2d):
        torch.nn.init.uniform_(m.weight.data, 0, 1)
        torch.nn.init.uniform_(m.bias.data, 0, 0.1)

# model.apply(weights_init)

for net in lock.transforms:
    net.apply(weights_init)

# %%
weights = lock.read_weights( 'iresnet','pretrained_weights/cifar10_iresnet_e16',)
lock.setup(weights)
# Out:
# reading success!
# Overwriting the weights...

# %%
lock.transforms[0]
# Out:
# Conv_iResNet(
#   (blocklist): ModuleList(
#     (0): conv_iresnet_block3(
#       (squeeze): squeeze()
#       (bottleneck_block): Sequential(
#         (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU()
#         (2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (3): ReLU()
#         (4): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#         (5): ReLU()
#         (6): Conv2d(32, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (7): ReLU()
#         (8): Conv2d(8, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#   )
# )

# %%
lock.train(base_model, train_loader, optimizer, criterion, scheduler, I=30, J=1, learning_rate = 0.1)

# %%
makedir('./pretrained_weights/cifar10_iresnet_e8_new')
lock.save('iresnet','pretrained_weights/cifar10_iresnet_e8_new')

# %%
eval_idx, total, correct = 0, 0, 0
for i, (images, labels) in enumerate(test_loader):
    images, labels = images.cuda(), labels.cuda()
#     images = lock.lock(images, labels).cuda()
    with torch.no_grad():
        logits = base_model(images)
        _, predicted = torch.max(logits.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
acc = correct / total
print('Accuracy %.2f' % (acc*100))

# %%
import os
path = 'trained_weights'
W, b = lock.W.cpu().detach().numpy(), lock.B.cpu().detach().numpy()
sname = 'cifar100e8'
np.save(os.path.join(path,'W_'+sname+'.npy'), W)
np.save(os.path.join(path,'B_'+sname+'.npy'), b)

# %%
# model = DenseNet.densenet_cifar()
model = ResNet.ResNet18(10)
model = model.cuda()
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(params=model.parameters(), lr=0.05, weight_decay=0.0005, momentum=0.9)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=30, eta_min=0)

train_loader,test_loader = dataset.load_cifar10(128)

# %%
# from tqdm import tqdm
for epoch in range(30):
    # Train
    model.train()
    acc_meter = AverageMeter()
    loss_meter = AverageMeter()
    pbar = tqdm(unlearnable_loader, total=len(train_loader))
    for images, labels in pbar:
        images, labels = images.cuda(), labels.cuda()
#         images = lock.lock(images, labels).cuda()
#         images = lock.unlock(images,labels).cuda()
        model.zero_grad()
        optimizer.zero_grad()
        logits = model(images)
        loss = criterion(logits, labels)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 5.0)
        optimizer.step()
        
        _, predicted = torch.max(logits.data, 1)
        acc = (predicted == labels).sum().item()/labels.size(0)
        acc_meter.update(acc)
        loss_meter.update(loss.item())
        pbar.set_description("Acc %.2f Loss: %.2f" % (acc_meter.avg*100, loss_meter.avg))
    scheduler.step()
    # Eval
    model.eval()
    correct, total = 0, 0
    for i, (images, labels) in enumerate(test_loader):
        images, labels = images.cuda(), labels.cuda()
        with torch.no_grad():
            logits = model(images)
            _, predicted = torch.max(logits.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            
            
    acc = correct / total
    tqdm.write('Clean Accuracy %.2f\n' % (acc*100))

# %%
data_iter = iter(train_loader)
imgs, lbs = next(data_iter)
imgs = imgs.cuda()
lbs = lbs.cuda()
show_images(imgs[:10])

# %%
imgs, lbs = next(data_iter)
imgs = imgs.cuda()
lbs = lbs.cuda()
show_images(imgs[:5])
pimages = lock.lock(imgs[:5], lbs[:5]).cuda()
rimages = lock.unlock(pimages, lbs[:5]).cuda()
pimages = pimages.detach()
rimages = rimages.detach()
show_images(pimages)
show_images(((imgs[:5].cpu()-pimages.cpu()))*255)
# show_images(rimages)
# show_images(((imgs[:5].cpu()-rimages.cpu()))*255)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
torch.max((pimages.cpu()))
# Out:
# tensor(1.0194)

# %%
imgs, lbs = next(data_iter)
imgs = imgs.cuda()
lbs = lbs.cuda()
pimages = lock.lock(imgs, lbs).cuda()
rimages = lock.unlock(pimages, lbs).cuda()
pimages = pimages.detach()
rimages = rimages.detach()


print(  torch.norm(imgs - pimages) )
print(  torch.norm(rimages - pimages) )
print(  torch.norm(imgs - rimages) )

# %%
l = []
for x in (imgs - pimages):
    l.append(torch.norm(x))
torch.mean(torch.tensor(l))
torch.std(torch.tensor(l))
l = []
for x in (rimages - pimages):
    l.append(torch.norm(x))
torch.mean(torch.tensor(l))
torch.std(torch.tensor(l))
l = []
for x in (imgs - rimages):
    l.append(torch.norm(x))
torch.mean(torch.tensor(l))
torch.std(torch.tensor(l))

# %%
torch.norm(torch.ones(32,32,3) * 0.0314)

# %%
import torchvision
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
batch_size = 256

train_transform = [
    #             transforms.RandomCrop(32, padding=4),
                transforms.RandomHorizontalFlip(),
                transforms.ToTensor(),
#                 transforms.Normalize((0.4914, 0.4822, 0.4465),
#                                         (0.2023, 0.1994, 0.2010))
    ]
test_transform = [
#             transforms.RandomCrop(32, padding=4),
            transforms.RandomHorizontalFlip(),
            transforms.ToTensor(),
#                 transforms.Normalize((0.4914, 0.4822, 0.4465),
#                                         (0.2023, 0.1994, 0.2010))
]
train_transform = transforms.Compose(train_transform)
test_transform = transforms.Compose(test_transform)




clean_train_dataset = datasets.CIFAR10(root='../datasets', train=True, download=True, transform=train_transform)
clean_test_dataset = datasets.CIFAR10(root='../datasets', train=False, download=True, transform=test_transform)


clean_train_loader = DataLoader(dataset=clean_train_dataset, batch_size=batch_size,
                                shuffle=False, pin_memory=True,
                                drop_last=False)

# %%
unlearnable_train_dataset = datasets.CIFAR10(root='../datasets', train=True, download=True, transform=train_transform)

# %%
device = 'cuda'
# perturb_noise = noise.mul(255).clamp_(0, 255).permute(0, 2, 3, 1).to('cpu').numpy()
unlearnable_train_dataset.data = unlearnable_train_dataset.data.astype(np.float32)
for i in tqdm(range(len(unlearnable_train_dataset))):
    # unlearnable_train_dataset.data[i] += perturb_noise[i]
    with torch.no_grad():
        d = torch.tensor(unlearnable_train_dataset.data[i] / 255, dtype=torch.float32 ).to(device)
        d = d.permute(2,0,1)
        # d = unlearnable_train_dataset[i][0].to(device)
        d = lock.transform_sample(d, unlearnable_train_dataset.targets[i])
        d = d.clamp(0,1)
        d = d.permute(1, 2, 0) * 255
        d = d.detach().cpu().numpy().astype(np.uint8)
    unlearnable_train_dataset.data[i] = d
unlearnable_train_dataset.data = unlearnable_train_dataset.data.astype(np.uint8)

# %%
unlearnable_loader = DataLoader(dataset=unlearnable_train_dataset, batch_size=128,
                                shuffle=True, pin_memory=True,
                                drop_last=False)

# %%
datait = iter(unlearnable_loader)
imgs, ls = next(datait)

# %%
i = 5
with torch.no_grad():
    d = torch.tensor(unlearnable_train_dataset.data[i] / 255, dtype=torch.float32 ).cuda()
    d = d.permute(2,0,1)
    d = lock.transform_sample(d, unlearnable_train_dataset.targets[i]).clamp(0,1)
    print(torch.min(d))
    d = d.permute(1, 2, 0) 
    d = d.detach().cpu().numpy()
    d = (d*255).astype(np.uint8)

# %%
d[31][16]

# %%
datait = iter(unlearnable_loader)
imgs, ls = next(datait)
xx = imgs[0].cuda()

# %%
from torch.utils.data import DataLoader
unlearnable_loader = DataLoader(dataset=unlearnable_train_dataset, batch_size=128,
                                shuffle=True, pin_memory=True,
                                drop_last=False, num_workers=0)

# %%
data_iter = iter(unlearnable_loader)
imgs, lbs = next(data_iter)
imgs = imgs.cuda()
lbs = lbs.cuda()
show_images(imgs[:10])

# %%
imgs[1]

# %%
import random
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline

def imshow(img):
    fig = plt.figure(figsize=(8, 8), dpi=80, facecolor='w', edgecolor='k')
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()
    
def get_pairs_of_imgs(idx):
    clean_img = clean_train_dataset.data[idx]
    unlearnable_img = unlearnable_train_dataset.data[idx]
    clean_img = torchvision.transforms.functional.to_tensor(clean_img)
    unlearnable_img = torchvision.transforms.functional.to_tensor(unlearnable_img)

    x = unlearnable_img - clean_img
    x_min = torch.min(x)
    x_max = torch.max(x)
    noise_norm = (x - x_min) / (x_max - x_min)
    noise_norm = torch.clamp(noise_norm, 0, 1)
    return [clean_img, noise_norm, unlearnable_img]
    
selected_idx = [random.randint(0, 50000) for _ in range(3)]
img_grid = []
for idx in selected_idx:
    img_grid += get_pairs_of_imgs(idx)
    

imshow(torchvision.utils.make_grid(torch.stack(img_grid), nrow=3, pad_value=255))

# %%
idx = 11
clean_img = clean_train_dataset.data[idx]
unlearnable_img = unlearnable_train_dataset.data[idx]

# %%
plt.imshow(unlearnable_img/255)

# %%
plt.imshow(clean_img)

# %%
np.mean(clean_img)

# %%
np.mean(unlearnable_img)

# %%
np.max(clean_img - unlearnable_img)

# %%
i = - 8/255
(- 16/255) / (1+ 16/255) * i + (8/255) / ( 1 + 16/255 )

# %%
i = (1 + 8/255)
(- 16/255) / (1+ 16/255) * i + (8/255) / ( 1 + 16/255 )

# %%
8/255
